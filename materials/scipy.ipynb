# %% [markdown]
# # scipy

# %%
# Numercial arrays.
import numpy as np

# Scientific Computing.
import scipy as sp

# Plotting.
import matplotlib.pyplot as plt

# %% [markdown]
# ## Resources
#
# https://docs.scipy.org/doc/scipy/tutorial/index.html

# %% [markdown]
# ## Fit a Line

# %%
# Range of x values.
x = np.linspace(-10.0, 10.0, 21)

# Range of y values.
y = 4.0 * x + 2.0 + np.random.normal(0.0, 3.0, x.shape)

# %%
# Plot x and y.
plt.plot(x, y, 'o', label='Data')

# %%
# Fit a line.
m, c = np.polyfit(x, y, 1)

# Show.
m, c
# Out:
# (np.float64(3.943670901176235), np.float64(2.249050530465297))

# %%
# Plot x and y.
plt.plot(x, y, 'o', label='Data')

# Plot the line.
plt.plot(x, m * x + c, label='Fit')

# %%
# Fit a line.
coeffs = np.polyfit(x, y, 1)

# Show.
coeffs
# Out:
# array([3.9436709 , 2.24905053])

# %%
# Evaluate the polynomial.
f = np.polyval(coeffs, x)

# Show.
f
# Out:
# array([-37.18765848, -33.24398758, -29.30031668, -25.35664578,
#        -21.41297488, -17.46930398, -13.52563307,  -9.58196217,
#         -5.63829127,  -1.69462037,   2.24905053,   6.19272143,
#         10.13639233,  14.08006323,  18.02373414,  21.96740504,
#         25.91107594,  29.85474684,  33.79841774,  37.74208864,
#         41.68575954])

# %%
# Show y.
y
# Out:
# array([-38.54591067, -32.28412863, -24.68247565, -25.97207541,
#        -22.45653801, -16.15399432, -15.17846769, -11.2087276 ,
#         -7.95162277,  -4.91412883,   4.36956976,   6.27053043,
#         13.40894491,  10.29704775,  23.5305649 ,  22.66849403,
#         25.94262397,  22.40840649,  36.17393283,  37.75113274,
#         43.7568829 ])

# %% [markdown]
# ## Evaluate
#
# https://en.wikipedia.org/wiki/Coefficient_of_determination

# %%
# Sum of squares of residuals.
ss_res = np.sum((y - f)**2)

# Show.
ss_res
# Out:
# np.float64(174.1052754027173)

# %%
# Mean of y.
y_bar = np.mean(y)

# Show.
y_bar
# Out:
# np.float64(2.249050530465297)

# %%
# Total sum of squares.
ss_tot = np.sum((y - y_bar)**2)

# Show.
ss_tot
# Out:
# np.float64(12149.561211526528)

# %%
# Ratio.
ss_res / ss_tot
# Out:
# np.float64(0.01433016982025163)

# %%
# R^2 value.
1.0 - (ss_res / ss_tot)
# Out:
# np.float64(0.9856698301797484)

# %% [markdown]
# ## Using scipy

# %%
# Use scipy to fit a line.
fit = sp.stats.linregress(x, y)

# Show.
fit
# Out:
# LinregressResult(slope=np.float64(3.9436709011762345), intercept=np.float64(2.249050530465297), rvalue=np.float64(0.9928090602828664), pvalue=np.float64(5.547192766547933e-19), stderr=np.float64(0.10908971375028359), intercept_stderr=np.float64(0.6605710209288802))

# %%
# Slope.
fit.slope
# Out:
# np.float64(3.9436709011762345)

# %%
# Intercept.
fit.intercept
# Out:
# np.float64(2.249050530465297)

# %%
# R value.
fit.rvalue
# Out:
# np.float64(0.9928090602828664)

# %% [markdown]
# The R-squared value is the square of the R-value.

# %%
# R2 value.
fit.rvalue**2
# Out:
# np.float64(0.9856698301797483)

# %% [markdown]
# ## End
